# %%
import matplotlib.pyplot as plt
import os
import sys
from pathlib import Path

sys.path.insert(0, str(Path.cwd().parent))
from neuro_bes.utility.dataloader import w7x_experimental_flap2database

# %%
path='/data2/W7-X/processed_data/APDCAM/flap_recon/'
dir_list=os.listdir(path)

# %%
dir_list_2025=[]
for i in dir_list:
    if i.startswith('2025'):
        dir_list_2025.append(i)

# %%
for shot in dir_list_2025[:10]:
    w7x_experimental_flap2database(path,shot)
