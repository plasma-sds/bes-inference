# %%
import matplotlib.pyplot as plt
import numpy as np

import sys
from pathlib import Path
sys.path.insert(0, str(Path.cwd().parent))
from neuro_bes.utility.dataloader import load_w7x_synthetic_data

# %%
bes_obj=load_w7x_synthetic_data("/home/molnarbalazs/data/BES_ML_modelling/W7X/W7Xinit-Na-E_50.0-t_8-q_2.0-zeff_1.5-tipte_1-mppmi_1-001.hdf5", "wsv11")

# %%
plt.plot(bes_obj.grid, bes_obj.emissions[20], label='emission')

# %%
plt.plot(bes_obj.grid, bes_obj.densities[20], label='density')

# %%
for i in (np.random.rand(100)*bes_obj.emissions.shape[0]).astype(int):
    plt.plot(bes_obj.emissions[i])

# %%
for i in (np.random.rand(100)*bes_obj.densities.shape[0]).astype(int):
    plt.plot(bes_obj.densities[i])
